# %% [markdown]
# <a href="https://colab.research.google.com/github/navaneeth-das/-CODSOFT/blob/main/Car_Sale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/bigdata/codsoft/car_purchasing.csv',encoding='ISO-8859-1')
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
df.tail()
# Out:
#     customer name                     customer e-mail      country  gender  \
# 495        Walter                 ligula@Cumsociis.ca        Nepal       0
# 496         Vanna  Cum.sociis.natoque@Sedmolestie.edu     Zimbabwe       1
# 497         Pearl       penatibus.et@massanonante.com  Philippines       1
# 498          Nell   Quisque.varius@arcuVivamussit.net     Botswana       1
# 499         Marla           Camaron.marla@hotmail.com       marlal       1
#
#            age  annual Salary  credit card debt    net worth  \
# 495  41.462515    71942.40291       6995.902524  541670.1016
# 496  37.642000    56039.49793      12301.456790  360419.0988
# 497  53.943497    68888.77805      10611.606860  764531.3203
# 498  59.160509    49811.99062      14013.034510  337826.6382
# 499  46.731152    61370.67766       9391.341628  462946.4924
#
#      car purchase amount
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# ...

# %%
df.shape
# Out:
# (500, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
df.describe()
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
df.isna().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth',
#        'car purchase amount'],
#       dtype='object')

# %%
df.drop(['customer name','customer e-mail'],axis=1,inplace=True)
df
# Out:
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount
# 0    238961.2505          35321.45877
# 1    530973.9078          45115.52566
# ...

# %%
df['country'].value_counts()
# Out:
# Israel                 6
# Mauritania             6
# Bolivia                6
# Greenland              5
# Saint Barthélemy       5
#                       ..
# El Salvador            1
# Denmark                1
# Oman                   1
# Trinidad and Tobago    1
# marlal                 1
# Name: country, Length: 211, dtype: int64

# %%
m=sns.countplot(x='gender',data=df)
m.bar_label(m.containers[0])
# Out:
# [Text(0, 0, '247'), Text(0, 0, '253')]

# %%
sns.pairplot(df)

# %%
sns.histplot(df['age'])
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(10,10))
cols =[ 'credit card debt','age', 'annual Salary', 'net worth']
for i in range(4):
    sns.scatterplot(x='car purchase amount', y=cols[i], data=df, ax=axes[i%2,i//2], hue='gender' )

# %%
corr=df.corr(method='kendall')
sns.heatmap(corr,annot=True,fmt='.3f',linewidths=.5)
plt.show()
# Out:
# <ipython-input-24-fba9fdea28d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr(method='kendall')

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['country']=label.fit_transform(df['country'])
df
# Out:
#      country  gender        age  annual Salary  credit card debt    net worth  \
# 0         27       0  41.851720    62812.09301      11609.380910  238961.2505
# 1         17       0  40.870623    66646.89292       9572.957136  530973.9078
# 2          1       1  43.152897    53798.55112      11160.355060  638467.1773
# 3         41       1  58.271369    79370.03798      14426.164850  548599.0524
# 4         26       1  57.313749    59729.15130       5358.712177  560304.0671
# ..       ...     ...        ...            ...               ...          ...
# 495      128       0  41.462515    71942.40291       6995.902524  541670.1016
# 496      208       1  37.642000    56039.49793      12301.456790  360419.0988
# 497      144       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       24       1  59.160509    49811.99062      14013.034510  337826.6382
# 499      209       1  46.731152    61370.67766       9391.341628  462946.4924
#
#      car purchase amount
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x=scaler.fit_transform(x)
y=scaler.fit_transform(y.values.reshape(-1,1))

# %%
x=df.drop(['car purchase amount'],axis=1)
x
# Out:
#      country  gender        age  annual Salary  credit card debt    net worth
# 0         27       0  41.851720    62812.09301      11609.380910  238961.2505
# 1         17       0  40.870623    66646.89292       9572.957136  530973.9078
# 2          1       1  43.152897    53798.55112      11160.355060  638467.1773
# 3         41       1  58.271369    79370.03798      14426.164850  548599.0524
# 4         26       1  57.313749    59729.15130       5358.712177  560304.0671
# ..       ...     ...        ...            ...               ...          ...
# 495      128       0  41.462515    71942.40291       6995.902524  541670.1016
# 496      208       1  37.642000    56039.49793      12301.456790  360419.0988
# 497      144       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       24       1  59.160509    49811.99062      14013.034510  337826.6382
# 499      209       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 6 columns]

# %%
y=df['car purchase amount']
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: car purchase amount, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#      country  gender        age  annual Salary  credit card debt    net worth
# 5        100       1  56.824893    68499.85162      14179.472440  428485.3604
# 116      128       1  43.031069    69175.19403       6039.594519  325701.4083
# 45       183       0  55.275143    70787.27764      10155.340950  853913.8532
# 16       185       0  44.742200    63259.87837      11495.549990  370356.2223
# 462      170       0  39.141035    66680.27410      10263.148990  556945.8742
# ..       ...     ...        ...            ...               ...          ...
# 106      184       0  41.796014    51075.46118      12416.848450  450402.2932
# 270       21       0  35.375156    33422.99683       8570.611562  211168.6293
# 348      112       0  45.305941    63561.04525       3730.119720  608019.6308
# 435      111       1  57.974293    41409.29390       8211.340920  421318.9764
# 102       20       1  30.492353    68289.18229       7357.787011  404457.3099
#
# [350 rows x 6 columns]

# %%
x_test
# Out:
#      country  gender        age  annual Salary  credit card debt    net worth
# 361       35       0  36.126918    74420.10254      10274.135580  551344.3365
# 73       168       1  47.789729    59139.21080       4630.544424  473845.8546
# 374        0       1  57.134576    67752.38329      13851.921220  657178.4135
# 155      140       0  50.219573    55381.53225       5088.239017   20000.0000
# 104      148       0  48.476396    63975.06090      10614.854490  891439.8761
# ..       ...     ...        ...            ...               ...          ...
# 266       58       1  40.362058    53921.33351       9046.181090  515305.4841
# 23       106       1  47.022284    52027.63837      11960.853770  688466.0503
# 222      207       0  47.450949    61063.35631      12066.265710  509543.0859
# 261       86       0  37.722824    49346.40500       5827.820346  479685.9824
# 426      114       1  41.931168    55514.99340       8009.719809  394229.8972
#
# [150 rows x 6 columns]

# %%
y_train
# Out:
# 5      56611.99784
# 116    42408.02625
# 45     68925.09447
# 16     41814.72067
# 462    44430.63323
#           ...
# 106    34803.82395
# 270    12536.93842
# 348    49348.88394
# 435    42139.64528
# 102    33640.73697
# Name: car purchase amount, Length: 350, dtype: float64

# %%
# using LinearRegression
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x_train,y_train)
y_pred1=model.predict(x_test)
y_pred1
# Out:
# array([43548.3891862, 45748.0435808, 62884.4719539, 35642.8568034,
#        58832.8131454, 59324.8961617, 51484.1122951, 54584.1392284,
#        48269.6708304, 48094.7006293, 37843.2731203, 44670.8080996,
#        45858.0287273, 39982.1992034, 40565.4622873, 54132.6799852,
#        48940.4355962, 19721.7300839, 58104.5242901, 49560.7305373,
#        42127.1229711, 52526.3887091, 53080.5200455, 37087.9699233,
#        39135.2426808, 37957.808868 , 62163.4134049, 47620.1325786,
#        23634.2538828, 53401.101916 , 55610.3072687, 47391.5830686,
#        39607.0317717, 53617.4288816, 42892.6101588, 39760.5645295,
#        57528.5615041, 31017.7317174, 42843.7865457, 38794.543447 ,
#        53998.7606465, 60783.4837789, 46402.6718601, 39502.1224484,
#        52903.1746476, 42478.8950218, 37958.558421 , 39718.5919462,
#        52738.6478366, 47037.081547 , 42982.1322511, 34556.1956729,
#        38304.2064891, 43976.2357958, 45119.7497306, 47370.2541435,
# ...

# %%
# Using a RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
model2=RandomForestRegressor()
model2.fit(x_train,y_train)
y_pred2= rf.predict(x_test)
y_pred2
# Out:
# array([43595.5176319, 44829.3398177, 62232.4298901, 35196.2580613,
#        59727.8453927, 59349.9368526, 51312.2880512, 54047.9695649,
#        48512.5452023, 48237.3570836, 37848.8908246, 44835.4486974,
#        45192.8034809, 39374.5376881, 40006.2951296, 52945.8791793,
#        48861.536251 , 20625.4663286, 58343.1714022, 51038.576506 ,
#        42333.2638883, 53308.0828927, 52942.5953502, 37168.480663 ,
#        37976.5689222, 37965.7176573, 62405.0646032, 48263.7547421,
#        23568.8690857, 53058.3493275, 55183.5701407, 47495.2487206,
#        40423.1971802, 53291.4464264, 42332.1915064, 39484.4719993,
#        57935.5541966, 31533.5127074, 42235.4486955, 38059.3580284,
#        54391.0863443, 61993.7450802, 47388.0787776, 39237.5580971,
#        52651.3691666, 42022.4942339, 37902.2241278, 39054.6802815,
#        52454.5803695, 47110.5750217, 43406.8794698, 34560.2282856,
#        37755.9571205, 44634.6383268, 45140.617592 , 46841.8776968,
# ...

# %%
# Using a DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
model3=DecisionTreeRegressor()
model3.fit(x_train,y_train)
y_pred3=model3.predict(x_test)
y_pred
# Out:
# array([43595.5176319, 44829.3398177, 62232.4298901, 35196.2580613,
#        59727.8453927, 59349.9368526, 51312.2880512, 54047.9695649,
#        48512.5452023, 48237.3570836, 37848.8908246, 44835.4486974,
#        45192.8034809, 39374.5376881, 40006.2951296, 52945.8791793,
#        48861.536251 , 20625.4663286, 58343.1714022, 51038.576506 ,
#        42333.2638883, 53308.0828927, 52942.5953502, 37168.480663 ,
#        37976.5689222, 37965.7176573, 62405.0646032, 48263.7547421,
#        23568.8690857, 53058.3493275, 55183.5701407, 47495.2487206,
#        40423.1971802, 53291.4464264, 42332.1915064, 39484.4719993,
#        57935.5541966, 31533.5127074, 42235.4486955, 38059.3580284,
#        54391.0863443, 61993.7450802, 47388.0787776, 39237.5580971,
#        52651.3691666, 42022.4942339, 37902.2241278, 39054.6802815,
#        52454.5803695, 47110.5750217, 43406.8794698, 34560.2282856,
#        37755.9571205, 44634.6383268, 45140.617592 , 46841.8776968,
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse

model_lst = [y_pred1,y_pred2,y_pred3]
model_names = ["Linear Regression", "Random Forest", "Decision Tree"]

for i in range(len(model_names)):
    print(f"Mean absolute error of {model_names[i]} = {mse(y_test, model_lst[i])}")

lm_score = r2_score(y_test,y_pred1)
rf_score = r2_score(y_test,y_pred2)
dt_score = r2_score(y_test,y_pred3)

accuracy = {"Multiple Linear Regression": lm_score,
            "Random Forest Regressor": rf_score,
            "Decision Tree Regressor": dt_score,}
print(f"\nThe {max(accuracy, key=accuracy.get)} model has the highest accuracy with value {max(accuracy.values()) * 100}%")
# Out:
# Mean absolute error of Linear Regression = 5346121.52015619
# Mean absolute error of Random Forest = 5790245.554074523
# Mean absolute error of Decision Tree = 12962489.059192847
#
# The Multiple Linear Regression model has the highest accuracy with value 94.98976660974864%
